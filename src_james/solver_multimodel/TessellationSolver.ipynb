# %%
from src_james.core.DataModel import Task
from src_james.solver_multimodel.TessellationSolver import TessellationSolver

# %%
task   = Task('test/27f8ce4f.json')
solver = TessellationSolver()
solver.plot([ task ])
# Out:
# <bound method TessellationSolver.action of <src_james.solver_multimodel.TessellationSolver.TessellationSolver object at 0x7f5d2c0eddd8>> {'preprocess': <function copy at 0x7f5d5f8b2b70>, 'p_arg': (), 'transform': <function copy at 0x7f5d5f8b2b70>, 't_arg': (), 'query': <function query_max_color at 0x7f5d2ec2c9d8>, 'q_arg': ()}
# solved:  TessellationSolver {'preprocess': <function copy at 0x7f5d5f8b2b70>, 'p_arg': (), 'transform': <function copy at 0x7f5d5f8b2b70>, 't_arg': (), 'query': <function query_max_color at 0x7f5d2ec2c9d8>, 'q_arg': ()}
# 1
