# %%
import numpy as np
import pandas as pd
import time
import sys
import os
import inspect
import json
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
root_dir = os.path.dirname(parent_dir)
sys.path.insert(0, parent_dir)
print(root_dir)
# Out:
# /Users/dolcera/kaggle/arc/kaggle-arc

# %%
from core.utils import plot_task, load_data, cmap

# %%
trains, evals = load_data(f'{root_dir}/input')
# Out:
# data loaded

# %%
tagged_tasks = pd.read_csv(f'{root_dir}/tagged_tasks.csv', index_col=0)

# %%
interested_task_id = 140
interested_task_details = tagged_tasks[tagged_tasks.index==140].to_dict(orient='records')[0]
interested_tags = []
for key in interested_task_details.keys():
    if interested_task_details[key] == 1:
        interested_tags.append(key)
similar_tasks = []
interested_tags_flag = []
for interested_tag in interested_tags:
    if len(interested_tags_flag) == 0:
        interested_tags_flag = (tagged_tasks[interested_tag] == 1)
    else:
        interested_tags_flag = (interested_tags_flag) & (tagged_tasks[interested_tag] == 1)
        
for similar_task_id in tagged_tasks[interested_tags_flag].index.values:
    similar_tasks.append(similar_task_id)

similar_tasks
# Out:
# [106, 135, 140, 167, 189, 247, 267, 287, 323, 326, 374, 377, 397]

# %%
interested_repeat_tasks = similar_tasks
for task_index in interested_repeat_tasks:
    print(task_index)
    plot_task(trains[task_index])
# Out:
# 106
# 135
# 140
# 167
# 189
# 247
# 267
# 287
# 323
# 326
# 374
# 377
# 397

# %%
interested_repeat_tasks = [140, 374, 326, 323, 247, 135, 189]
for task_index in interested_repeat_tasks:
    print(task_index)
    plot_task(trains[task_index])
    plot_task(trains[task_index], bw=True)
# Out:
# 140
# 374
# 326
# 323
# 247
# 135
# 189

# %%
plot_task(trains[140])
plot_task(trains[140], bw=True)

# %%
class Grid:
    
class Neurons:
    def __init__(self, input:Grid, output:Grid):
        pass
    
class RepeatNeurons:
    def __init__(self):
        pass
    
    def
# Out:
#   File "<ipython-input-10-48cf5e250c4a>", line 3
#     class Neurons:
#         ^
# IndentationError: expected an indented block
