json
# /kaggle/input/abstraction-and-reasoning-challenge/training/4612dd53.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/aedd82e4.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/321b1fc6.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/90c28cc7.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/a699fb00.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/e50d258f.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/e9afcf9a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/b94a9452.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/caa06a1f.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/29c11459.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/2dd70a9a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/f8ff0b80.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/9dfd6313.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/25d8a9c8.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/aabf363d.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/445eab21.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/40853293.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/6d75e8bb.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/b27ca6d3.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/846bdb03.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/b190f7f5.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/feca6190.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/ff805c23.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/67a423a3.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/f25fbde4.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/dc433765.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/9af7a82c.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/44d8ac46.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/ea786f4a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/67e8384a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/253bf280.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/25ff71a9.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/d4f3cd78.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/c3e719e8.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/48d8fb45.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/6f8cd79b.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/cf98881b.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/447fd412.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/c8f0f002.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/31aa019c.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/cbded52d.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/cdecee7f.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/d89b689b.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/6773b310.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/f9012d9b.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/0d3d703e.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/b9b7f026.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/b6afb2da.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/3ac3eb23.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/09629e4f.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/0e206a2e.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/a3df8b1e.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/508bd3b6.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/4c4377d9.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/00d62c1b.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/28bf18c6.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/ef135b50.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/3aa6fb7a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/db3e9e38.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/dc1df850.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/d23f8c26.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/9ecd008a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/a2fd1cf0.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/e21d9049.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/7468f01a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/1c786137.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/fcc82909.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/a68b268e.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/6aa20dc0.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/178fcbfb.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/1e0a9b12.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/c444b776.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/d9fac9be.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/f35d900a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/97999447.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/363442ee.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/a87f7484.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/f8a8fe49.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/a8d7556c.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/662c240a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/5daaa586.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/aba27056.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/9d9215db.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/54d82841.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/780d0b14.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/25d487eb.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/80af3007.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/1f642eb9.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/46f33fce.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/b775ac94.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/017c7c7b.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/46442a0e.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/c0f76784.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/06df4c85.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/db93a21d.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/228f6490.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/b60334d2.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/e509e548.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/e98196ab.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/57aa92db.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/dbc1a6ce.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/4347f46a.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/2bcee788.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/d13f3404.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/6d0160f0.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/4938f0c2.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/dae9d2b5.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/d5d6de2d.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/85c4e7cd.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/1e32b0e9.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/0dfd9992.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/0b148d64.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/f2829549.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/7df24a62.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/39a8645d.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/39e1d7f9.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/b0c4d837.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/ce9e57f2.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/d6ad076f.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/d406998b.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/eb5a1d5d.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/e9614598.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/de1cd16c.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/8e1813be.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/a61ba2ce.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/95990924.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/7837ac64.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/bbc9ae5d.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/50cb2852.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/7c008303.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/3bd67248.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/1cf80156.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/63613498.json
# /kaggle/input/abstraction-and-reasoning-challenge/training/a3325580.json

# %%
import numpy as np
import pandas as pd

import os
import json
from pathlib import Path

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
from xgboost import XGBClassifier
import pdb



data_path = Path('/kaggle/input/abstraction-and-reasoning-challenge/')
training_path = data_path / 'training'
evaluation_path = data_path / 'evaluation'
test_path = data_path / 'test'

def plot_result(test_input, test_prediction,
                input_shape):
    """
    Plots the first train and test pairs of a specified task,
    using same color scheme as the ARC app
    """
    cmap = colors.ListedColormap(
        ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
         '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
    norm = colors.Normalize(vmin=0, vmax=9)
    fig, axs = plt.subplots(1, 2, figsize=(15,15))
    test_input = test_input.reshape(input_shape[0],input_shape[1])
    axs[0].imshow(test_input, cmap=cmap, norm=norm)
    axs[0].axis('off')
    axs[0].set_title('Actual Target')
    test_prediction = test_prediction.reshape(input_shape[0],input_shape[1])
    axs[1].imshow(test_prediction, cmap=cmap, norm=norm)
    axs[1].axis('off')
    axs[1].set_title('Model Prediction')
    plt.tight_layout()
    plt.show()
    
def plot_test(test_prediction, task_name):
    """
    Plots the first train and test pairs of a specified task,
    using same color scheme as the ARC app
    """
    cmap = colors.ListedColormap(
        ['#000000', '#0074D9','#FF4136','#2ECC40','#FFDC00',
         '#AAAAAA', '#F012BE', '#FF851B', '#7FDBFF', '#870C25'])
    norm = colors.Normalize(vmin=0, vmax=9)
    fig, axs = plt.subplots(1, 1, figsize=(15,15))
    axs.imshow(test_prediction, cmap=cmap, norm=norm)
    axs.axis('off')
    axs.set_title(f'Test Prediction {task_name}')
    plt.tight_layout()
    plt.show()
    
# https://www.kaggle.com/inversion/abstraction-and-reasoning-starter-notebook
def flattener(pred):
    str_pred = str([row for row in pred])
    str_pred = str_pred.replace(', ', '')
    str_pred = str_pred.replace('[[', '|')
    str_pred = str_pred.replace('][', '|')
    str_pred = str_pred.replace(']]', '|')
    return str_pred



sample_sub = pd.read_csv(data_path/'sample_submission.csv')
sample_sub = sample_sub.set_index('output_id')
sample_sub.head()

def get_moore_neighbours(color, cur_row, cur_col, nrows, ncols):

    if cur_row<=0: top = -1
    else: top = color[cur_row-1][cur_col]
        
    if cur_row>=nrows-1: bottom = -1
    else: bottom = color[cur_row+1][cur_col]
        
    if cur_col<=0: left = -1
    else: left = color[cur_row][cur_col-1]
        
    if cur_col>=ncols-1: right = -1
    else: right = color[cur_row][cur_col+1]
        
    return top, bottom, left, right

def get_tl_tr(color, cur_row, cur_col, nrows, ncols):
        
    if cur_row==0:
        top_left = -1
        top_right = -1
    else:
        if cur_col==0: top_left=-1
        else: top_left = color[cur_row-1][cur_col-1]
        if cur_col==ncols-1: top_right=-1
        else: top_right = color[cur_row-1][cur_col+1]   
        
    return top_left, top_right

def make_features(input_color, nfeat):
    nrows, ncols = input_color.shape
    feat = np.zeros((nrows*ncols,nfeat))
    cur_idx = 0
    for i in range(nrows):
        for j in range(ncols):
            feat[cur_idx,0] = i
            feat[cur_idx,1] = j
            feat[cur_idx,2] = input_color[i][j]
            feat[cur_idx,3:7] = get_moore_neighbours(input_color, i, j, nrows, ncols)
            feat[cur_idx,7:9] = get_tl_tr(input_color, i, j, nrows, ncols)
            feat[cur_idx,9] = len(np.unique(input_color[i,:]))
            feat[cur_idx,10] = len(np.unique(input_color[:,j]))
            feat[cur_idx,11] = (i+j)
            feat[cur_idx,12] = len(np.unique(input_color[i-local_neighb:i+local_neighb,
                                                         j-local_neighb:j+local_neighb]))

            cur_idx += 1
        
    return feat

def features(task, mode='train'):
    num_train_pairs = len(task[mode])
    feat, target = [], []
    
    global local_neighb
    for task_num in range(num_train_pairs):
        input_color = np.array(task[mode][task_num]['input'])
        #print(input_color)
        target_color = task[mode][task_num]['output']
        #print(target_color)
        nrows, ncols = len(task[mode][task_num]['input']), len(task[mode][task_num]['input'][0])

        target_rows, target_cols = len(task[mode][task_num]['output']), len(task[mode][task_num]['output'][0])
        
        if (target_rows!=nrows) or (target_cols!=ncols):
            print('Number of input rows:',nrows,'cols:',ncols)
            print('Number of target rows:',target_rows,'cols:',target_cols)
            not_valid=1
            return None, None, 1

        imsize = nrows*ncols
        #offset = imsize*task_num*3 #since we are using three types of aug
        feat.extend(make_features(input_color, nfeat))
        target.extend(np.array(target_color).reshape(-1,))
            
    return np.array(feat), np.array(target), 0

# mode = 'eval'
mode = 'test'
if mode=='eval':
    task_path = evaluation_path
elif mode=='train':
    task_path = training_path
elif mode=='test':
    task_path = test_path

all_task_ids = sorted(os.listdir(task_path))

nfeat = 13
local_neighb = 5
valid_scores = {}

model_accuracies = {'ens': []}
pred_taskids = []

for task_id in all_task_ids:

    task_file = str(task_path / task_id)
    with open(task_file, 'r') as f:
        task = json.load(f)

    feat, target, not_valid = features(task)
    if not_valid:
        print('ignoring task', task_file)
        print()
        not_valid = 0
        continue

    xgb =  XGBClassifier(n_estimators=10, n_jobs=-1)
    xgb.fit(feat, target, verbose=-1)


#     training on input pairs is done.
#     test predictions begins here

    num_test_pairs = len(task['test'])
    for task_num in range(num_test_pairs):
        cur_idx = 0
        input_color = np.array(task['test'][task_num]['input'])
        nrows, ncols = len(task['test'][task_num]['input']), len(
            task['test'][task_num]['input'][0])
        feat = make_features(input_color, nfeat)

        print('Made predictions for ', task_id[:-5])

        preds = xgb.predict(feat).reshape(nrows,ncols)
        
        if (mode=='train') or (mode=='eval'):
            ens_acc = (np.array(task['test'][task_num]['output'])==preds).sum()/(nrows*ncols)

            model_accuracies['ens'].append(ens_acc)

            pred_taskids.append(f'{task_id[:-5]}_{task_num}')

            print('ensemble accuracy',(np.array(task['test'][task_num]['output'])==preds).sum()/(nrows*ncols))
            print()

        preds = preds.astype(int).tolist()
        plot_test(preds, task_id)
        sample_sub.loc[f'{task_id[:-5]}_{task_num}',
                       'output'] = flattener(preds)
        


if (mode=='train') or (mode=='eval'):
    df = pd.DataFrame(model_accuracies, index=pred_taskids)
    print(df.head(10))

    print(df.describe())
    for c in df.columns:
        print(f'for {c} no. of complete tasks is', (df.loc[:, c]==1).sum())

    df.to_csv('ens_acc.csv')



sample_sub.head()



sample_sub.to_csv('submission.csv')
# Out:
# Number of input rows: 2 cols: 2
# Number of target rows: 6 cols: 6
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/00576224.json
#
# Made predictions for  009d5c81
# Made predictions for  00dbd492
# Made predictions for  03560426
# Made predictions for  05a7bcf2
# Made predictions for  0607ce86
# Number of input rows: 3 cols: 3
# Number of target rows: 9 cols: 9
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/0692e18c.json
#
# Made predictions for  070dd51e
# Made predictions for  08573cc6
# Number of input rows: 30 cols: 30
# Number of target rows: 4 cols: 4
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/0934a4d8.json
#
# Made predictions for  09c534e7
# Number of input rows: 30 cols: 30
# Number of target rows: 3 cols: 3
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/0a1d4ef5.json
#
# Made predictions for  0a2355a6
# Made predictions for  0b17323b
# Number of input rows: 12 cols: 13
# Number of target rows: 6 cols: 6
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/0bb8deee.json
#
# Made predictions for  0becf7df
# Number of input rows: 3 cols: 4
# Number of target rows: 6 cols: 8
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/0c786b71.json
#
# Number of input rows: 13 cols: 4
# Number of target rows: 6 cols: 4
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/0c9aba6e.json
#
# Made predictions for  0d87d2a6
# Made predictions for  0e671a1a
# Made predictions for  0f63c0b9
# Made predictions for  103eff5b
# Made predictions for  11e1fe23
# Made predictions for  12422b43
# Number of input rows: 11 cols: 14
# Number of target rows: 3 cols: 9
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/12997ef3.json
#
# Made predictions for  12eac192
# Number of input rows: 7 cols: 15
# Number of target rows: 7 cols: 7
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/136b0064.json
#
# Made predictions for  13713586
# Made predictions for  137f0df0
# Made predictions for  140c817e
# Made predictions for  14754a24
# Made predictions for  15113be4
# Made predictions for  15663ba9
# Number of input rows: 3 cols: 3
# Number of target rows: 9 cols: 9
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/15696249.json
#
# Made predictions for  16b78196
# Made predictions for  17b80ad2
# Made predictions for  17cae0c1
# Made predictions for  18419cfa
# Made predictions for  184a9768
# Number of input rows: 5 cols: 13
# Number of target rows: 5 cols: 6
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/195ba7dc.json
#
# Number of input rows: 23 cols: 23
# Number of target rows: 7 cols: 7
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/1990f7a8.json
#
# Number of input rows: 13 cols: 15
# Number of target rows: 2 cols: 2
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/19bb5feb.json
#
# Number of input rows: 8 cols: 12
# Number of target rows: 1 cols: 1
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/1a2e2828.json
#
# Number of input rows: 19 cols: 13
# Number of target rows: 6 cols: 7
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/1a6449f1.json
#
# Made predictions for  1acc24af
# Made predictions for  1c02dbbe
# Made predictions for  1c0d0a4b
# Made predictions for  1c56ad9f
# Made predictions for  1d0a4b61
# Made predictions for  1d398264
# Made predictions for  1d398264
# Made predictions for  1da012fc
# Made predictions for  1e81d6f9
# Made predictions for  1e97544e
# Number of input rows: 23 cols: 25
# Number of target rows: 3 cols: 7
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/2037f2c7.json
#
# Number of input rows: 3 cols: 3
# Number of target rows: 6 cols: 6
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/2072aba6.json
#
# Number of input rows: 14 cols: 15
# Number of target rows: 6 cols: 8
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/20818e16.json
#
# Made predictions for  20981f0e
# Made predictions for  212895b5
# Made predictions for  21f83797
# Made predictions for  22a4bbc2
# Made predictions for  25094a63
# Made predictions for  2546ccf6
# Made predictions for  256b0a75
# Made predictions for  2685904e
# Number of input rows: 9 cols: 7
# Number of target rows: 15 cols: 15
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/2697da3f.json
#
# Number of input rows: 16 cols: 16
# Number of target rows: 3 cols: 3
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/2753e76c.json
#
# Made predictions for  27a77e38
# Number of input rows: 3 cols: 3
# Number of target rows: 9 cols: 9
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/27f8ce4f.json
#
# Number of input rows: 4 cols: 19
# Number of target rows: 4 cols: 4
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/281123b4.json
#
# Made predictions for  292dd178
# Made predictions for  29700607
# Made predictions for  2a5f8217
# Made predictions for  2b01abd0
# Number of input rows: 23 cols: 23
# Number of target rows: 7 cols: 8
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/2c0b0aff.json
#
# Made predictions for  2c737e39
# Number of input rows: 20 cols: 23
# Number of target rows: 9 cols: 9
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/2f0c5170.json
#
# Number of input rows: 2 cols: 2
# Number of target rows: 6 cols: 6
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/310f3251.json
#
# Number of input rows: 20 cols: 20
# Number of target rows: 3 cols: 3
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/3194b014.json
#
# Made predictions for  319f2597
# Made predictions for  31adaf00
# Number of input rows: 6 cols: 5
# Number of target rows: 3 cols: 5
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/31d5ba1a.json
#
# Made predictions for  32e9702f
# Made predictions for  332efdb3
# Made predictions for  3391f8c0
# Made predictions for  33b52de3
# Made predictions for  3490cc26
# Number of input rows: 5 cols: 9
# Number of target rows: 5 cols: 4
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/34b99a2b.json
#
# Number of input rows: 15 cols: 13
# Number of target rows: 3 cols: 13
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/351d6448.json
#
# Number of input rows: 14 cols: 18
# Number of target rows: 5 cols: 5
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/358ba94e.json
#
# Made predictions for  37d3e8b2
# Number of input rows: 5 cols: 5
# Number of target rows: 10 cols: 10
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/3979b1a8.json
#
# Made predictions for  3a301edc
# Number of input rows: 7 cols: 7
# Number of target rows: 3 cols: 3
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/3b4c2228.json
#
# Number of input rows: 12 cols: 6
# Number of target rows: 3 cols: 6
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/3d31c5b3.json
#
# Made predictions for  3ed85e70
# Number of input rows: 23 cols: 29
# Number of target rows: 5 cols: 5
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/3ee1011a.json
#
# Made predictions for  3f23242b
# Made predictions for  40f6cd08
# Number of input rows: 18 cols: 22
# Number of target rows: 12 cols: 11
# ignoring task /kaggle/input/abstraction-and-reasoning-challenge/test/414297c0.json
#
# Made predictions for  423a55dc
