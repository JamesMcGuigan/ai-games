# %% [markdown]
# # SingleColorSolver

# %%
from IPython.core.display import display, HTML
from src.datamodel.Competition import Competition
from src.solver_multimodel.solvers.SingleColorSolver import SingleColorSolver

# %load_ext autoreload
# %autoreload 2

competition = Competition()
solver      = SingleColorSolver()

# Detects

# %%
for name, dataset in competition.items():
    display(HTML(f'<h1>{name}</h1?'))
    solver.plot_detects(dataset)
# Out:
# <h1>training</h1?
# guess : training/27a28665.json SingleColorSolver None
# solved: training/445eab21.json SingleColorSolver ('<function:max_color>',)
# guess : training/44f52bb0.json SingleColorSolver None
# solved: training/5582e5ca.json SingleColorSolver ('<function:max_color>',)
# <h1>evaluation</h1?
# guess : evaluation/3194b014.json SingleColorSolver None
# <h1>test</h1?
# test  : test/3194b014.json SingleColorSolver None
