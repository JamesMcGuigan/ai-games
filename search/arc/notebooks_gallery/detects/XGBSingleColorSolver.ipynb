# %% [markdown]
# # XGBSingleColorSolver

# %%
from IPython.core.display import display
from IPython.core.display import HTML

from src.datamodel.Competition import Competition
from src.solver_multimodel.solvers.XGBSingleColorSolver import XGBSingleColorSolver

# %load_ext autoreload
# %autoreload 2

competition = Competition()
solver = XGBSingleColorSolver()

# %% [markdown]
# # Detects

# %%
for name, dataset in competition.items():
    display(HTML(f'<h1>{name}</h1?'))
    solver.plot_detects(dataset)
# Out:
# <h1>training</h1?
# guess : training/445eab21.json XGBSingleColorSolver [4]
# guess : training/5582e5ca.json XGBSingleColorSolver [6]
# guess : evaluation/3194b014.json XGBSingleColorSolver [4]
# test  : test/3194b014.json XGBSingleColorSolver [4]
# <h1>evaluation</h1?
# <h1>test</h1?
