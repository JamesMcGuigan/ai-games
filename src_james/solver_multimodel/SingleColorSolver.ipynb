# %%
from IPython.core.display import display, HTML
from src_james.core.DataModel import Competition
from src_james.solver_multimodel.SingleColorSolver import SingleColorSolver

# %load_ext autoreload
# %autoreload 2

competition = Competition()
solver = SingleColorSolver()

# %% [markdown]
# # Solved

# %%
for name, dataset in competition.items():
    display(HTML(f'<h1>{name}</h1>'))
    solver.plot(dataset)
# Out:
# <h1>training</h1>
# solved: training/5582e5ca.json SingleColorSolver None
# solved: training/445eab21.json SingleColorSolver None
# <h1>evaluation</h1>
# <h1>test</h1>

# %% [markdown]
# # Detects

# %%
for name, dataset in competition.items():
    display(HTML(f'<h1>{name}</h1?'))
    solver.plot_detects(dataset)
