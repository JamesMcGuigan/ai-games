# %%
from src_james.core.DataModel import Task, Competition
from submission.submission import XGBSolver

# %load_ext autoreload
# %autoreload 2

# %%
# task   = Task('test/27f8ce4f.json')
# solver.plot_detects([ task ])

# %%
competition = Competition()
solver = XGBSolver(booster='gbtree', n_estimators=2)
solver.verbose = False
competition['evaluation'].apply(solver.solve_all)
print(competition)
for task in competition['evaluation']:
    if task.score():
        solver.plot([task])
# Out:
# training   : {'correct': 0, 'guesses': 0, 'total': 416, 'error': 1.0, 'time': '00:00:00', 'name': 'training'}
# evaluation : {'correct': 6, 'guesses': 27, 'total': 419, 'error': 0.9857, 'time': '00:01:57', 'name': 'evaluation'}
# test       : {'correct': 0.0, 'guesses': 0, 'total': 104, 'error': 1.0, 'time': '00:00:00', 'name': 'test'}
# time       : 00:00:00

# %%
competition = Competition()
solver = XGBSolver(booster='dart')
solver.verbose = False
competition['evaluation'].apply(solver.solve_all)
print(competition)
for task in competition['evaluation']:
    if task.score():
        solver.plot([task])
# Out:
# training   : {'correct': 0, 'guesses': 0, 'total': 416, 'error': 1.0, 'time': '00:00:00', 'name': 'training'}
# evaluation : {'correct': 10, 'guesses': 237, 'total': 419, 'error': 0.9761, 'time': '00:00:00', 'name': 'evaluation'}
# test       : {'correct': 0.0, 'guesses': 0, 'total': 104, 'error': 1.0, 'time': '00:00:00', 'name': 'test'}
# time       : 00:00:00

# %%
competition = Competition()
solver = XGBSolver(booster='gblinear')
solver.verbose = False
competition['evaluation'].apply(solver.solve_all)
print(competition)
for task in competition['evaluation']:
    if task.score():
        solver.plot([task])
# Out:
# training   : {'correct': 0, 'guesses': 0, 'total': 416, 'error': 1.0, 'time': '00:00:00', 'name': 'training'}
# evaluation : {'correct': 3, 'guesses': 31, 'total': 419, 'error': 0.9928, 'time': '00:00:00', 'name': 'evaluation'}
# test       : {'correct': 0.0, 'guesses': 0, 'total': 104, 'error': 1.0, 'time': '00:00:00', 'name': 'test'}
# time       : 00:00:00

# %%
competition = Competition()
solver = XGBSolver(objective='reg:tweedie')
solver.verbose = False
solver.solve_all(competition['evaluation'])
print(competition)
for task in competition['evaluation']:
    if task.score():
        solver.plot([task])

# %% [markdown]
# # Training

# %%
# competition = Competition()
# solver.plot(competition['training'])

# %% [markdown]
# # Evaluation

# %%
# solver.plot(competition['evaluation'])

# %% [markdown]
# # Test

# %%
# solver.plot(competition['test'])
