# %% [markdown]
# # TessellationSolver

# %%
from src.datamodel.Competition import Competition
from src.datamodel.Task import Task
from src.solver_multimodel.solvers.TessellationSolver import TessellationSolver
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Task

# %%
task   = Task('test/27f8ce4f.json')
solver = TessellationSolver()
solver.plot([ task ])
# Out:
# test  : test/27f8ce4f.json TessellationSolver {'preprocess': <function copy at 0x7f6b84066b70>, 'p_arg': (), 'transform': <function copy at 0x7f6b84066b70>, 't_arg': (), 'query': <function query_max_color at 0x7f6b531d30d0>, 'q_arg': ()}
# 1

# %% [markdown]
# # Training

# %%
competition = Competition()
competition
# Out:
# {'training': <Dataset:/home/jamie/code/kaggle-arc/./input/training>, 'evaluation': <Dataset:/home/jamie/code/kaggle-arc/./input/evaluation>, 'test': <Dataset:/home/jamie/code/kaggle-arc/./input/test>}

# %%
solver.plot_detects(competition['training'])
# Out:
# solved: training/007bbfb7.json TessellationSolver {'preprocess': <function copy at 0x7f6b84066b70>, 'p_arg': (), 'transform': <function copy at 0x7f6b84066b70>, 't_arg': (), 'query': <function query_not_zero at 0x7f6b531e1e18>, 'q_arg': ()}
# guess : training/3af2c5a8.json TessellationSolver None
# guess : training/46442a0e.json TessellationSolver None
# guess : training/46f33fce.json TessellationSolver None
# solved: training/4c4377d9.json TessellationSolver None
# guess : training/539a4f51.json TessellationSolver None
# guess : training/62c24649.json TessellationSolver None
# guess : training/67e8384a.json TessellationSolver None
# solved: training/6d0aefbc.json TessellationSolver None
# guess : training/6fa7a44f.json TessellationSolver None
# guess : training/794b24be.json TessellationSolver None
# /home/jamie/code/kaggle-arc/src/util/plot.py:30: RuntimeWarning: divide by zero encountered in double_scalars
#   font_size     = 50 / np.sqrt(input_matrix.shape[0] * input_matrix.shape[1])
# /home/jamie/code/kaggle-arc/src/util/plot.py:33: UserWarning: Attempting to set identical left == right == -0.5 results in singular transformations; automatically expanding.
#   ax.imshow(input_matrix, cmap=cmap, norm=norm)
# /home/jamie/code/kaggle-arc/src/util/plot.py:33: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   ax.imshow(input_matrix, cmap=cmap, norm=norm)
# guess : training/7fe24cdd.json TessellationSolver None
# guess : training/8be77c9e.json TessellationSolver None
# guess : training/8d5021e8.json TessellationSolver None
# guess : training/91413438.json TessellationSolver None
# solved: training/963e52fc.json TessellationSolver None
# solved: training/a416b8f3.json TessellationSolver {'preprocess': <function copy at 0x7f6b84066b70>, 'p_arg': (), 'transform': <function copy at 0x7f6b84066b70>, 't_arg': (), 'query': <function query_true at 0x7f6b531e19d8>, 'q_arg': ()}
# guess : training/ac0a08a4.json TessellationSolver None
# guess : training/b91ae062.json TessellationSolver None
# guess : training/bbc9ae5d.json TessellationSolver None
# solved: training/c3e719e8.json TessellationSolver {'preprocess': <function copy at 0x7f6b84066b70>, 'p_arg': (), 'transform': <function copy at 0x7f6b84066b70>, 't_arg': (), 'query': <function query_max_color at 0x7f6b531d30d0>, 'q_arg': ()}
# guess : training/c9e6f938.json TessellationSolver None
# solved: training/cce03e0d.json TessellationSolver {'preprocess': <function copy at 0x7f6b84066b70>, 'p_arg': (), 'transform': <function copy at 0x7f6b84066b70>, 't_arg': (), 'query': <function query_count_colors at 0x7f6b531d7840>, 'q_arg': ()}
# guess : training/d13f3404.json TessellationSolver None
# guess : training/feca6190.json TessellationSolver None
# 25

# %% [markdown]
# # Evaluation

# %%
solver.plot_detects(competition['evaluation'])
# Out:
# guess : evaluation/00576224.json TessellationSolver None
# guess : evaluation/0692e18c.json TessellationSolver None
# guess : evaluation/0c786b71.json TessellationSolver None
# guess : evaluation/15696249.json TessellationSolver None
# solved: evaluation/27f8ce4f.json TessellationSolver {'preprocess': <function copy at 0x7f6b84066b70>, 'p_arg': (), 'transform': <function copy at 0x7f6b84066b70>, 't_arg': (), 'query': <function query_max_color at 0x7f6b531d30d0>, 'q_arg': ()}
# guess : evaluation/3979b1a8.json TessellationSolver None
# guess : evaluation/48131b3c.json TessellationSolver None
# guess : evaluation/48f8583b.json TessellationSolver None
# guess : evaluation/59341089.json TessellationSolver None
# solved: evaluation/5b6cbef5.json TessellationSolver {'preprocess': <function copy at 0x7f6b84066b70>, 'p_arg': (), 'transform': <function copy at 0x7f6b84066b70>, 't_arg': (), 'query': <function query_not_zero at 0x7f6b531e1e18>, 'q_arg': ()}
# guess : evaluation/7953d61e.json TessellationSolver None
# guess : evaluation/833dafe3.json TessellationSolver None
# guess : evaluation/8719f442.json TessellationSolver None
# guess : evaluation/8b28cd80.json TessellationSolver None
# guess : evaluation/8e2edd66.json TessellationSolver None
# solved: evaluation/a59b95c0.json TessellationSolver None
# guess : evaluation/ad7e01d0.json TessellationSolver None
# guess : evaluation/bc4146bd.json TessellationSolver None
# guess : evaluation/c48954c1.json TessellationSolver None
# guess : evaluation/cad67732.json TessellationSolver None
# guess : evaluation/ccd554ac.json TessellationSolver None
# guess : evaluation/d4b1c2b1.json TessellationSolver None
# guess : evaluation/ed98d772.json TessellationSolver None
# 23

# %% [markdown]
# # Test

# %%
solver.plot_detects(competition['test'])
# Out:
# test  : test/00576224.json TessellationSolver None
# test  : test/0692e18c.json TessellationSolver None
# test  : test/0c786b71.json TessellationSolver None
# test  : test/15696249.json TessellationSolver None
# test  : test/27f8ce4f.json TessellationSolver {'preprocess': <function copy at 0x7f6b84066b70>, 'p_arg': (), 'transform': <function copy at 0x7f6b84066b70>, 't_arg': (), 'query': <function query_max_color at 0x7f6b531d30d0>, 'q_arg': ()}
# test  : test/3979b1a8.json TessellationSolver None
# 6
