# %%
import os
import time
from IPython.core.display import display, HTML
from src.datamodel.Competition import Competition
from src.solver_multimodel.solvers import solvers

# %load_ext autoreload
# %autoreload 2

# %%
time_start   = time.perf_counter()
competition  = Competition()
scores       = { name: 0 for name in competition.values() }
for solver in solvers:
    display(HTML(f'<h1>{solver.__class__.__name__}</h1>'))
    time_start_dataset = time.perf_counter()
    for name, dataset in competition.items():
        solver.verbose = False
        solver.debug   = False
        solver.cache = {}
        scores[name] = solver.plot(dataset)

    dataset.time_taken = time.perf_counter() - time_start_dataset
competition.time_taken = time.perf_counter() - time_start
# Out:
# <h1>DoNothingSolver</h1>
# <h1>BorderSolver</h1>
# <h1>GeometrySolver</h1>
# <h1>SingleColorSolver</h1>
# <h1>TessellationSolver</h1>
# <h1>ZoomSolver</h1>

# %%
for key, value in competition.score().items(): print(f'{key.rjust(11)}: {value}')
# Out:
#    training: {'correct': 18, 'total': 416, 'error': 0.9567, 'time': '00:00:00', 'name': 'training'}
#  evaluation: {'correct': 4, 'total': 419, 'error': 0.9905, 'time': '00:00:00', 'name': 'evaluation'}
#        test: {'correct': 0, 'total': 104, 'error': 1.0, 'time': '00:00:03', 'name': 'test'}
#        time: 00:02:10
