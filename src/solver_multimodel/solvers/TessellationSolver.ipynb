# %%
from src.datamodel.DataModel import Task, Competition
from src.solver_multimodel.TessellationSolver import TessellationSolver

# %load_ext autoreload
# %autoreload 2

# %%
task   = Task('test/27f8ce4f.json')
solver = TessellationSolver()
solver.plot([ task ])
# Out:
# <bound method TessellationSolver.action of <src.solver_multimodel.TessellationSolver.TessellationSolver object at 0x7fe425627160>> {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_max_color at 0x7fe3e0b298c8>, 'q_arg': ()}
# solved:  TessellationSolver {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_max_color at 0x7fe3e0b298c8>, 'q_arg': ()}
# 1

# %% [markdown]
# # Training

# %%
competition = Competition()
competition
# Out:
# {'training': <Dataset:/home/jamie/code/kaggle-arc/./input/training>, 'evaluation': <Dataset:/home/jamie/code/kaggle-arc/./input/evaluation>, 'test': <Dataset:/home/jamie/code/kaggle-arc/./input/test>}

# %%
solver.plot_detects(competition['training'])
# Out:
# <bound method TessellationSolver.action of <src.solver_multimodel.TessellationSolver.TessellationSolver object at 0x7fe425627160>> {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_max_color at 0x7fe3e0b298c8>, 'q_arg': ()}
# solved:  TessellationSolver {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_max_color at 0x7fe3e0b298c8>, 'q_arg': ()}
# <bound method TessellationSolver.action of <src.solver_multimodel.TessellationSolver.TessellationSolver object at 0x7fe425627160>> {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_true at 0x7fe3f55442f0>, 'q_arg': ()}
# solved:  TessellationSolver {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_true at 0x7fe3f55442f0>, 'q_arg': ()}
# <bound method TessellationSolver.action of <src.solver_multimodel.TessellationSolver.TessellationSolver object at 0x7fe425627160>> {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_not_zero at 0x7fe3e0b29488>, 'q_arg': ()}
# solved:  TessellationSolver {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_not_zero at 0x7fe3e0b29488>, 'q_arg': ()}
# <bound method TessellationSolver.action of <src.solver_multimodel.TessellationSolver.TessellationSolver object at 0x7fe425627160>> {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_count_colors at 0x7fe3e0b570d0>, 'q_arg': ()}
# solved:  TessellationSolver {'preprocess': <function copy at 0x7fe4241889d8>, 'p_arg': (), 'transform': <function copy at 0x7fe4241889d8>, 't_arg': (), 'query': <function query_count_colors at 0x7fe3e0b570d0>, 'q_arg': ()}
# 24

# %% [markdown]
# # Evaluation

# %%
solver.plot_detects(competition['evaluation'])

# %% [markdown]
# # Test

# %%
solver.plot_detects(competition['test'])
